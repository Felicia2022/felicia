# %% [markdown]
# # Mục mới

# %%
chinese=10
english=20
math=30
total=chinese+english+math
print(total)
# Out:
# 60

# %%
scoreChinese=10
scoreEnglish=20
scoreMathematics=30
print(total)
# Out:
# 60

# %% [markdown]
# # Mục mới

# %%
a=10
b=20
c=30
d=a+b+c
print(total)
# Out:
# 60
